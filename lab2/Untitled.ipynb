# %%
# %run lab.py
# Out:
# None
# {4724}
# ...

# %%
# %run test.py
# Out:
# test_01 (__main__.TestActedTogether) ... ok
# test_02 (__main__.TestActedTogether) ... ok
# test_03 (__main__.TestActedTogether) ... ok
# test_06 (__main__.TestActorPath) ... ok
# test_07 (__main__.TestActorPath) ... ok
# test_08 (__main__.TestActorPath) ... ok
# test_09 (__main__.TestActorPath) ... ok
# test_04 (__main__.TestBaconNumber) ... ok
# test_05 (__main__.TestBaconNumber) ... ok
# test_10 (__main__.TestBaconPath) ... ok
# test_11 (__main__.TestBaconPath) ... ok
# test_12 (__main__.TestBaconPath) ... ok
# test_13 (__main__.TestBaconPath) ... ok
# test_14 (__main__.TestBaconPath) ... ok
# test_15 (__main__.TestBaconPath) ... ok
# test_01 (__main__.TestTiny) ... ok
# test_Bacon_number_0 (__main__.TestTiny) ... ok
# test_Bacon_number_1 (__main__.TestTiny) ... ok
# test_Bacon_number_2 (__main__.TestTiny) ... ok
# test_Bacon_path (__main__.TestTiny) ... ok
# test_path (__main__.TestTiny) ... ok
#
# ----------------------------------------------------------------------
# ...

# %%
d = {1:[]}
d[1].append(23)
if 3 in d:
    print('a')
else:
    d[3] = set([456])
print(d)

# %%
l =
